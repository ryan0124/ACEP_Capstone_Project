# %% [markdown]
# # Open Street Map Buildings Information
#
# This notebook demonstrates downloading data from Open Street Map to fill gaps in the [Global Electricity Transmission And Distribution Lines](https://datacatalog.worldbank.org/dataset/derived-map-global-electricity-transmission-and-distribution-lines) (GETD) dataset.
#
# To obtain GIS data from Open Street Map of any specified administrative area in the world, the [GeoFabrik](http://download.geofabrik.de/) download server is the easiest solution for querying data at the administrative level.
#
# In this notebook, we address obtaining data for areas of Alaska
#
# We will download the latest version of this data (currently 12/20/21) and extract the commercial, industrial and residential buildings information.
#
#
# #Resources
# * https://wiki.openstreetmap.org/wiki/Map_features#Power
# * https://dlr-ve-esy.gitlab.io/esy-osmfilter/main.html
# * https://stackoverflow.com/questions/66367195/get-all-ways-by-using-esy-osmfilter

# %% [markdown]
# ### Mount Drive folder
#
# Mount Drive folder for saving this data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Get packages
#
# Install packages needed for analysis and import into workspace.

# %%
# !pip install esy-osmfilter # gives tags and filters to open street map data
# !pip install geopandas #to make working with geospatial data in python easier
# %load_ext autoreload
# %autoreload 2
# Out:
# Collecting esy-osmfilter
#   Downloading esy_osmfilter-1.0.11-py3-none-any.whl (30 kB)
# Requirement already satisfied: protobuf<4,>=3 in /usr/local/lib/python3.7/dist-packages (from esy-osmfilter) (3.17.3)
# Collecting esy-osm-pbf>=0
#   Downloading esy_osm_pbf-0.0.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf<4,>=3->esy-osmfilter) (1.15.0)
# Installing collected packages: esy-osm-pbf, esy-osmfilter
# Successfully installed esy-osm-pbf-0.0.1 esy-osmfilter-1.0.11
# Collecting geopandas
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 9.7 MB/s
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 12.4 MB/s
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.1.post1)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.21-cp37-cp37m-manylinux2014_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 192 kB/s
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2018.9)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.21 geopandas-0.10.2 munch-2.5.0 pyproj-3.2.1

# %%
import configparser, contextlib
import os, sys
import geopandas as gpd
import pandas as pd
from esy.osmfilter import osm_colors as CC
from esy.osmfilter import run_filter 
from esy.osmfilter import Node, Way, Relation
from esy.osmfilter import export_geojson
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### To Downlaod the main pbf file (No need to run)

# %%
## NO NEED TO RUN
# !wget http://download.geofabrik.de/north-america/us/alaska-latest.osm.pbf -P '/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'
# Out:
# --2022-03-09 04:44:44--  http://download.geofabrik.de/north-america/us/alaska-latest.osm.pbf
# Resolving download.geofabrik.de (download.geofabrik.de)... 95.216.28.113, 116.202.112.212
# Connecting to download.geofabrik.de (download.geofabrik.de)|95.216.28.113|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 118348072 (113M) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/alaska-latest.osm.pbf.4’
#
# alaska-latest.osm.p 100%[===================>] 112.87M  19.8MB/s    in 6.9s
#
# 2022-03-09 04:44:51 (16.4 MB/s) - ‘/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/alaska-latest.osm.pbf.4’ saved [118348072/118348072]

# %% [markdown]
# # Function to download different types of buildings

# %%
# Getting residential buildings
def get_res_buildings(area_name): 
  
 # Set input/output locations
  PBF_inputfile = os.path.join(os.getcwd(), '/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-latest.osm.pbf')
  JSON_outputfile = os.path.join(os.getcwd(),'/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-res_buildings.json')
  
  # Pre-filter for all residential buildings
  prefilter={Node: {}, Way: {"building":["apartments","bungalow","cabin","detached","dormitory","farm",
                                          "hotel","house","residential","church","garage","garages",],
                             "tourism":["alpine_hut","apartment","hostel","hotel","motel",
                                        ],
                             "addr":[True,],}, Relation: {}}
  whitefilter = []
  blackfilter = []
  
  # Create initial data
  [Data, _]=run_filter('noname',
                    PBF_inputfile, 
                    JSON_outputfile, 
                    prefilter,
                    whitefilter,
                    blackfilter,
                    NewPreFilterData=True, 
                    CreateElements=False, 
                    LoadElements=False,
                    verbose=True)  
  # # Check that data exists
  print(len(Data['Way']))
  
  # # Get residential buildings elements
  whitefilter=[(("building","apartments"),), (("building","bungalow"),),(("building","cabin"),),
               (("building","detached"),), (("building","dormitory"),),(("building","farm"),),
               (("building","hotel"),), (("building","house"),),(("building","residential"),),
               (("building","church"),), (("building","garage"),),(("building","garages"),),
               (("tourism","alpine_hut"),), (("tourism","apartment"),),(("tourism","hostel"),),
               (("tourism","hotel"),), (("tourism","motel"),),(("addr",True),),
               ]
  blackfilter=[((),),]
 
  # Apply filter
  [Data, Elements]=run_filter('powerlines',
                        PBF_inputfile, 
                        JSON_outputfile, 
                        prefilter,
                        whitefilter, 
                        blackfilter, 
                        NewPreFilterData=False, 
                        CreateElements=True, 
                        LoadElements=False,
                        verbose=True)
  
  print(len(Data['Way']))

  
  # Export data to geojson
  export_geojson(Elements['powerlines']['Way'],Data, filename='/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-res_buildings.geojson',jsontype='Line')
  
  # Read data into geopandas
  gdf = gpd.read_file('/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-res_buildings.geojson')
  
  # Write as shapefile
  gdf.to_file('/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-res_buildings.shp')
  
  #Plot output
  gdf.plot()

# %%
# Getting commercial buildings
def get_com_buildings(area_name): 
  
 # Set input/output locations
  PBF_inputfile = os.path.join(os.getcwd(), '/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-latest.osm.pbf')
  JSON_outputfile = os.path.join(os.getcwd(),'/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-com_buildings.json')
  
  # Pre-filter for all commercial buildings
  prefilter={Node: {"amenity":["charging_staion","atm","strip_club",],}, Way: {"aeroway":["terminal",],"amenity":["bar","cafe","fast_food","food_court","pub","restaurant","college","kindergarten",
                                                                "library","school","university","bus_station","car_rental","car_wash",
                                                                "fuel","bank","clinic","dentist",
                                                                "doctor","hospital","nursing_home","pharmacy","socail_facility",
                                                                "veterinary","brothel","casino","cinema","community_centre",
                                                                "conference_centre","gambling","love_hotel","night_club",
                                                                "planetarium","studio","swingerclub",
                                                                "theatre","courthouse","embassy","fire_station",
                                                                "police","post_office","prison","townhall",
                                                                "creamatorium","internet_cafe","place_of_worship",],
                             "building":["commerical","office","retail","supermarket","warehouse","bakehouse","civic","college","fire_station",
                                         "government","hospital","kindergarten","public","school","train_staion","transportaion",
                                         "university","stadium","parking",],
                             "leisure":["adult_gaming_centre","amusement_arcade","beach_resort","fitness_centre",
                                        "sports_centre","stadium","summer_camp",],
                             "office":["accountant","association","charity","company","comsulting","courier",
                                       "dipomatic","educational_institution","employment_agency","engineer",
                                       "estate_agent","financial","forestry","foundation","government","insurance",
                                       "lawyer","logistics","moving_company","ngo","political_party",
                                       "property_management","religion","research","security","tax_advisor","telecommunication",
                                       "union","water_utility","yes"],
                             "shop":[True],
                             "tourism":["aquarium","gallery","museum","zoo","yes"],
                             "addr":[True,],}, Relation: {}}
  whitefilter = []
  blackfilter = []
  
  # Create initial data
  [Data, _]=run_filter('noname',
                    PBF_inputfile, 
                    JSON_outputfile, 
                    prefilter,
                    whitefilter,
                    blackfilter,
                    NewPreFilterData=True, 
                    CreateElements=False, 
                    LoadElements=False,
                    verbose=True)  
  # # Check that data exists
  print(len(Data['Node']))
  
  # # Get commercial buildings elements
  whitefilter=[(("aeroway","terminal"),), (("amenity","bar"),), (("amenity","cafe"),), (("amenity","fast_food"),), (("amenity","food_court"),), (("amenity","pub"),), (("amenity","restaurant"),), 
               (("amenity","college"),), (("amenity","kindergarten"),), (("amenity","library"),), (("amenity","school"),), (("amenity","university"),), (("amenity","bus_station"),),
               (("amenity","car_rental"),), (("amenity","car_wash"),), (("amenity","fuel"),), (("amenity","bank"),), (("amenity","clinic"),), (("amenity","dentist"),), (("amenity","doctor"),),
               (("amenity","hospital"),), (("amenity","nursing_home"),), (("amenity","pharmacy"),), (("amenity","socail_facility"),), (("amenity","veterinary"),), (("amenity","brothel"),), 
               (("amenity","casino"),), (("amenity","cinema"),), (("amenity","community_centre"),), (("amenity","conference_centre"),), (("amenity","gambling"),), (("amenity","love_hotel"),),
               (("amenity","night_club"),), (("amenity","planetarium"),), (("amenity","studio"),), (("amenity","swingerclub"),), (("amenity","theatre"),), (("amenity","courthouse"),),
               (("amenity","embassy"),), (("amenity","fire_station"),), (("amenity","police"),), (("amenity","post_office"),), (("amenity","prison"),), (("amenity","townhall"),), (("amenity","creamatorium"),),
               (("amenity","internet_cafe"),), (("amenity","place_of_worship"),), (("building","commerical"),), (("building","office"),), (("building","retail"),), (("building","supermarket"),),
               (("building","warehouse"),), (("building","bakehouse"),), (("building","civic"),), (("building","college"),), (("building","fire_station"),), (("building","government"),),
               (("building","hospital"),), (("building","kindergarten"),), (("building","public"),), (("building","school"),), (("building","train_staion"),), (("building","transportaion"),),
               (("building","university"),), (("building","stadium"),), (("building","parking"),), (("leisure","adult_gaming_centre"),), (("leisure","amusement_arcade"),), (("leisure","beach_resort"),),
               (("leisure","amusement_arcade"),), (("leisure","amusement_arcade"),), (("leisure","amusement_arcade"),), (("leisure","amusement_arcade"),), (("leisure","amusement_arcade"),),
               (("leisure","fitness_centre"),), (("leisure","sports_centre"),), (("leisure","stadium"),), (("leisure","summer_camp"),), (("office","accountant"),), (("office","association"),),
               (("office","charity"),), (("office","company"),), (("office","comsulting"),), (("office","courier"),), (("office","dipomatic"),), (("office","educational_institution"),),
               (("office","employment_agency"),), (("office","engineer"),), (("office","estate_agent"),), (("office","financial"),), (("office","forestry"),), (("office","foundation"),),
               (("office","government"),), (("office","insurance"),), (("office","lawyer"),), (("office","logistics"),), (("office","moving_company"),), (("office","ngo"),),
               (("office","political_party"),), (("office","property_management"),), (("office","religion"),), (("office","research"),), (("office","security"),), (("office","tax_advisor"),),
               (("office","telecommunication"),), (("office","union"),), (("office","water_utility"),), (("office","yes"),), (("shop",True),), (("tourism","aquarium"),), (("tourism","gallery"),),
               (("tourism","museum"),), (("tourism","yes"),), (("addr",True),),
               ]
  blackfilter=[((),),]
 
  # Apply filter
  [Data, Elements]=run_filter('powerlines',
                        PBF_inputfile, 
                        JSON_outputfile, 
                        prefilter,
                        whitefilter, 
                        blackfilter, 
                        NewPreFilterData=False, 
                        CreateElements=True, 
                        LoadElements=False,
                        verbose=True)
  
  print(len(Data['Node']))

  # Export data to geojson
  export_geojson(Elements['powerlines']['Way'],Data, filename='/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-com_buildings.geojson',jsontype='Line')
  
  # Read data into geopandas
  gdf = gpd.read_file('/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-com_buildings.geojson')
  
  # Write as shapefile
  gdf.to_file('/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-com_buildings.shp')
  
  #Plot output
  gdf.plot()

# %%
# Getting industrial buildings
def get_ind_buildings(area_name): 
  
 # Set input/output locations
  PBF_inputfile = os.path.join(os.getcwd(), '/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-latest.osm.pbf')
  JSON_outputfile = os.path.join(os.getcwd(),'/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-ind_buildings.json')
  
# Pre-filter for all industrial buildings
  prefilter={Node: {}, Way: {"building":["industrial","digestor","service","transformer_tower","water_tower",
                                         "military",],
                             "historic":["creamery",],
                             "man_made":["lighthouse","monitoring_station","observatory",
                                        "pumping_staition","wastewater_plant","water_works",
                                        "works",],
                             "military":["base","barracks",],
                             "public_transport":["station",],
                             "railway":["station",],
                             "telecom":["data_center",],
                             "water":["wastewater",],
                             "waterway":["dock","boatyard",],
                             "addr":[True,],
                             }, Relation: {}}
  whitefilter = []
  blackfilter = []
  
  # Create initial data
  [Data, _]=run_filter('noname',
                    PBF_inputfile, 
                    JSON_outputfile, 
                    prefilter,
                    whitefilter,
                    blackfilter,
                    NewPreFilterData=True, 
                    CreateElements=False, 
                    LoadElements=False,
                    verbose=True)  
  # # Check that data exists
  print(len(Data['Node']))
  
  # Get industrial buildings elements
  whitefilter=[(("building","industrial"),), (("building","digestor"),), (("building","service"),), (("building","transformer_tower"),), (("building","water_tower"),), (("building","military"),),
               (("historic","creamery"),), (("military","barracks"),), (("military","base"),), (("public_transport","station"),), (("railway","station"),), (("telecom","data_center"),), 
               (("water","wastewater"),), (("waterway","dock"),), (("waterway","boatyard"),), (("addr",True),), (("man_made","lighthouse"),), (("man_made","monitoring_station"),),
               (("man_made","observatory"),), (("man_made","wastewater_plant"),), (("man_made","pumping_staition"),), (("man_made","water_works"),), (("man_made","works"),),
              ]
  blackfilter=[((),),]
 
  # Apply filter
  [Data, Elements]=run_filter('powerlines',
                        PBF_inputfile, 
                        JSON_outputfile, 
                        prefilter,
                        whitefilter, 
                        blackfilter, 
                        NewPreFilterData=False, 
                        CreateElements=True, 
                        LoadElements=False,
                        verbose=True)
  
  print(len(Data['Node']))
  #data = Data['Way']
  #df = pd.DataFrame(data)
  #return (df)

  #return (Data['Way'])

  # Export data to geojson
  export_geojson(Elements['powerlines']['Way'],Data, filename='/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-ind_buildings.geojson',jsontype='Line')
  
  # Read data into geopandas
  gdf = gpd.read_file('/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-ind_buildings.geojson')
  
  # Write as shapefile
  gdf.to_file('/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/'+area_name+'-ind_buildings.shp')
  
  #Plot output
  gdf.plot()

# %%
# commercial buildings data
get_com_buildings('alaska')
# Out:
# INFO:esy.osmfilter.pre_filter:PreFilter OSM GAS DATA
# INFO:esy.osmfilter.pre_filter:InputFile     : /content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/alaska-latest.osm.pbf
# INFO:esy.osmfilter.pre_filter:Size          : 118070          kbyte
# INFO:esy.osmfilter.pre_filter:Estimated Time: 16.87           s
# INFO:esy.osmfilter.pre_filter:=============================
# INFO:esy.osmfilter.pre_filter:0.5
# INFO:esy.osmfilter.pre_filter:1
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# ...
# WARNING:fiona._env:Normalized/laundered field name: 'check_date:opening_hours' to 'check_date'
# WARNING:fiona._env:Normalized/laundered field name: 'community:gender' to 'community_'
# WARNING:fiona._env:Normalized/laundered field name: 'community_centre' to 'communit_1'
# WARNING:fiona._env:Normalized/laundered field name: 'community_centre:for' to 'communit_2'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:email' to 'contact_em'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:facebook' to 'contact_fa'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:fax' to 'contact__1'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:instagram' to 'contact_in'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:phone' to 'contact_ph'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:pobox' to 'contact_po'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:postcode' to 'contact__2'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:twitter' to 'contact_tw'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:website' to 'contact_we'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:youtube' to 'contact_yo'
# WARNING:fiona._env:Normalized/laundered field name: 'denomination' to 'denominati'
# WARNING:fiona._env:Normalized/laundered field name: 'description' to 'descriptio'
# WARNING:fiona._env:Normalized/laundered field name: 'designation' to 'designatio'
# WARNING:fiona._env:Normalized/laundered field name: 'diet:vegetarian' to 'diet_veget'
# WARNING:fiona._env:Normalized/laundered field name: 'disused:shop' to 'disused_sh'
# WARNING:fiona._env:Normalized/laundered field name: 'drive_through' to 'drive_thro'
# WARNING:fiona._env:Normalized/laundered field name: 'fire_station:type' to 'fire_stati'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:diesel' to 'fuel_diese'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:gasohol' to 'fuel_gasoh'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:gasoline' to 'fuel_gasol'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:gasoline_87' to 'fuel_gas_1'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:gasoline_88.5' to 'fuel_gas_2'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:gasoline_90' to 'fuel_gas_3'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:gasoline_91' to 'fuel_gas_4'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:gasoline_93' to 'fuel_gas_5'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:lpg' to 'fuel_lpg'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:octane_87' to 'fuel_octan'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:octane_89' to 'fuel_oct_1'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:octane_91' to 'fuel_oct_2'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:octane_92' to 'fuel_oct_3'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:octane_95' to 'fuel_oct_4'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:petrol' to 'fuel_petro'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:propane' to 'fuel_propa'
# WARNING:fiona._env:Normalized/laundered field name: 'fuel:unleaded' to 'fuel_unlea'
# WARNING:fiona._env:Normalized/laundered field name: 'gnis:county_name' to 'gnis_count'
# WARNING:fiona._env:Normalized/laundered field name: 'gnis:feature_id' to 'gnis_featu'
# WARNING:fiona._env:Normalized/laundered field name: 'gnis:import_uuid' to 'gnis_impor'
# WARNING:fiona._env:Normalized/laundered field name: 'gnis:reviewed' to 'gnis_revie'
# WARNING:fiona._env:Normalized/laundered field name: 'guide:adventure' to 'guide_adve'
# WARNING:fiona._env:Normalized/laundered field name: 'guide:canoeing' to 'guide_cano'
# WARNING:fiona._env:Normalized/laundered field name: 'guide:fishing' to 'guide_fish'
# WARNING:fiona._env:Normalized/laundered field name: 'guide:kayaking' to 'guide_kaya'
# WARNING:fiona._env:Normalized/laundered field name: 'health_facility' to 'health_fac'
# WARNING:fiona._env:Normalized/laundered field name: 'health_facility_type' to 'health_f_1'
# WARNING:fiona._env:Normalized/laundered field name: 'health_person:type' to 'health_per'
# WARNING:fiona._env:Normalized/laundered field name: 'healthcare:counselling' to 'healthca_1'
# WARNING:fiona._env:Normalized/laundered field name: 'healthcare:for' to 'healthca_2'
# WARNING:fiona._env:Normalized/laundered field name: 'healthcare:speciality' to 'healthca_3'
# WARNING:fiona._env:Normalized/laundered field name: 'heritage:operator' to 'heritage_o'
# WARNING:fiona._env:Normalized/laundered field name: 'information' to 'informatio'
# WARNING:fiona._env:Normalized/laundered field name: 'internet_access' to 'internet_a'
# WARNING:fiona._env:Normalized/laundered field name: 'internet_access:fee' to 'internet_1'
# WARNING:fiona._env:Normalized/laundered field name: 'is_in:city' to 'is_in_city'
# WARNING:fiona._env:Normalized/laundered field name: 'is_in:county' to 'is_in_coun'
# WARNING:fiona._env:Normalized/laundered field name: 'isced:level' to 'isced_leve'
# WARNING:fiona._env:Normalized/laundered field name: 'microbrewery' to 'microbrewe'
# WARNING:fiona._env:Normalized/laundered field name: 'name:1' to 'name_1'
# WARNING:fiona._env:Normalized/laundered field name: 'name:en' to 'name_en'
# WARNING:fiona._env:Normalized/laundered field name: 'name:etymology:wikidata' to 'name_etymo'
# WARNING:fiona._env:Normalized/laundered field name: 'name:ru' to 'name_ru'
# WARNING:fiona._env:Normalized/laundered field name: 'name:tli' to 'name_tli'
# WARNING:fiona._env:Normalized/laundered field name: 'name:zh' to 'name_zh'
# WARNING:fiona._env:Normalized/laundered field name: 'note:source' to 'note_sourc'
# WARNING:fiona._env:Normalized/laundered field name: 'nrhp:criteria' to 'nrhp_crite'
# WARNING:fiona._env:Normalized/laundered field name: 'nrhp:inscription_date' to 'nrhp_inscr'
# WARNING:fiona._env:Normalized/laundered field name: 'official_name' to 'official_n'
# WARNING:fiona._env:Normalized/laundered field name: 'opening_hours' to 'opening_ho'
# WARNING:fiona._env:Normalized/laundered field name: 'opening_hours:covid19' to 'opening__1'
# WARNING:fiona._env:Normalized/laundered field name: 'opening_hours:tours' to 'opening__2'
# WARNING:fiona._env:Normalized/laundered field name: 'operator:short' to 'operator_s'
# WARNING:fiona._env:Normalized/laundered field name: 'operator:type' to 'operator_t'
# WARNING:fiona._env:Normalized/laundered field name: 'operator:wikidata' to 'operator_w'
# WARNING:fiona._env:Normalized/laundered field name: 'operator:wikipedia' to 'operator_1'
# WARNING:fiona._env:Normalized/laundered field name: 'outdoor_seating' to 'outdoor_se'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:american_express' to 'payment_am'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:bitcoin' to 'payment_bi'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:bitcoincash' to 'payment__1'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:cash' to 'payment_ca'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:cheque' to 'payment_ch'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:coins' to 'payment_co'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:credit_cards' to 'payment_cr'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:debit_cards' to 'payment_de'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:dogecoin' to 'payment_do'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:litecoin' to 'payment_li'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:mastercard' to 'payment_ma'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:visa' to 'payment_vi'
# WARNING:fiona._env:Normalized/laundered field name: 'polling_station' to 'polling_st'
# WARNING:fiona._env:Normalized/laundered field name: 'postal_code' to 'postal_cod'
# WARNING:fiona._env:Normalized/laundered field name: 'protection_title' to 'protection'
# WARNING:fiona._env:Normalized/laundered field name: 'public_transport' to 'public_tra'
# WARNING:fiona._env:Normalized/laundered field name: 'ref:isil' to 'ref_isil'
# WARNING:fiona._env:Normalized/laundered field name: 'ref:nrhp' to 'ref_nrhp'
# WARNING:fiona._env:Normalized/laundered field name: 'ref:walmart' to 'ref_walmar'
# WARNING:fiona._env:Normalized/laundered field name: 'reservation' to 'reservatio'
# WARNING:fiona._env:Normalized/laundered field name: 'roof:colour' to 'roof_colou'
# WARNING:fiona._env:Normalized/laundered field name: 'roof:levels' to 'roof_level'
# WARNING:fiona._env:Normalized/laundered field name: 'roof:shape' to 'roof_shape'
# WARNING:fiona._env:Normalized/laundered field name: 'seamark:building:function' to 'seamark_bu'
# WARNING:fiona._env:Normalized/laundered field name: 'second_hand' to 'second_han'
# WARNING:fiona._env:Normalized/laundered field name: 'self_service' to 'self_servi'
# WARNING:fiona._env:Normalized/laundered field name: 'service:bicycle:repair' to 'service_bi'
# WARNING:fiona._env:Normalized/laundered field name: 'service:bicycle:retail' to 'service__1'
# WARNING:fiona._env:Normalized/laundered field name: 'service_times' to 'service_ti'
# WARNING:fiona._env:Normalized/laundered field name: 'shop:art' to 'shop_art'
# WARNING:fiona._env:Normalized/laundered field name: 'social_facility' to 'social_fac'
# WARNING:fiona._env:Normalized/laundered field name: 'social_facility:for' to 'social_f_1'
# WARNING:fiona._env:Normalized/laundered field name: 'source:date' to 'source_dat'
# WARNING:fiona._env:Normalized/laundered field name: 'source:name' to 'source_nam'
# WARNING:fiona._env:Normalized/laundered field name: 'source:position' to 'source_pos'
# WARNING:fiona._env:Normalized/laundered field name: 'source:url' to 'source_url'
# WARNING:fiona._env:Normalized/laundered field name: 'subject:wikipedia' to 'subject_wi'
# WARNING:fiona._env:Normalized/laundered field name: 'swimming_pool' to 'swimming_p'
# WARNING:fiona._env:Normalized/laundered field name: 'theatre:genre' to 'theatre_ge'
# WARNING:fiona._env:Normalized/laundered field name: 'theatre:type' to 'theatre_ty'
# WARNING:fiona._env:Normalized/laundered field name: 'toilets:disposal' to 'toilets_di'
# WARNING:fiona._env:Normalized/laundered field name: 'toilets:wheelchair' to 'toilets_wh'
# WARNING:fiona._env:Normalized/laundered field name: 'tower:type' to 'tower_type'
# WARNING:fiona._env:Normalized/laundered field name: 'townhall:type' to 'townhall_t'
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.

# %%
# industrial buildings data
get_ind_buildings('alaska')
# Out:
# INFO:esy.osmfilter.pre_filter:PreFilter OSM GAS DATA
# INFO:esy.osmfilter.pre_filter:InputFile     : /content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/alaska-latest.osm.pbf
# INFO:esy.osmfilter.pre_filter:Size          : 118070          kbyte
# INFO:esy.osmfilter.pre_filter:Estimated Time: 16.87           s
# INFO:esy.osmfilter.pre_filter:=============================
# INFO:esy.osmfilter.pre_filter:0.5
# INFO:esy.osmfilter.pre_filter:1
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.3
# INFO:esy.osmfilter.pre_filter:2
# INFO:esy.osmfilter.pre_filter:3
# INFO:esy.osmfilter.pre_filter:Outputfile    : /content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/alaska-ind_buildings.json
# Size          : 1426            kbyte
# Time Elapsed  : 175.83          s
# 5567
# 5567
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:74: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# WARNING:fiona._env:Normalized/laundered field name: 'addr:city' to 'addr_city'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:country' to 'addr_count'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:housenumber' to 'addr_house'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:postcode' to 'addr_postc'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:province' to 'addr_provi'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:state' to 'addr_state'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:street' to 'addr_stree'
# WARNING:fiona._env:Normalized/laundered field name: 'aerialway:access' to 'aerialway_'
# WARNING:fiona._env:Normalized/laundered field name: 'boresight_heading' to 'boresight_'
# WARNING:fiona._env:Normalized/laundered field name: 'building:levels' to 'building_l'
# WARNING:fiona._env:Normalized/laundered field name: 'building:part' to 'building_p'
# WARNING:fiona._env:Normalized/laundered field name: 'description' to 'descriptio'
# WARNING:fiona._env:Normalized/laundered field name: 'designation' to 'designatio'
# WARNING:fiona._env:Normalized/laundered field name: 'generator:method' to 'generator_'
# WARNING:fiona._env:Normalized/laundered field name: 'generator:source' to 'generato_1'
# WARNING:fiona._env:Normalized/laundered field name: 'gnis:feature_id' to 'gnis_featu'
# WARNING:fiona._env:Normalized/laundered field name: 'gnis:id' to 'gnis_id'
# WARNING:fiona._env:Normalized/laundered field name: 'gnis:name' to 'gnis_name'
# WARNING:fiona._env:Normalized/laundered field name: 'heritage:operator' to 'heritage_o'
# WARNING:fiona._env:Normalized/laundered field name: 'internet_access' to 'internet_a'
# WARNING:fiona._env:Normalized/laundered field name: 'monitoring:radiation' to 'monitoring'
# WARNING:fiona._env:Normalized/laundered field name: 'monitoring:seismic_activity' to 'monitori_1'
# WARNING:fiona._env:Normalized/laundered field name: 'monitoring:weather' to 'monitori_2'
# WARNING:fiona._env:Normalized/laundered field name: 'plant:method' to 'plant_meth'
# WARNING:fiona._env:Normalized/laundered field name: 'plant:output:electricity' to 'plant_outp'
# WARNING:fiona._env:Normalized/laundered field name: 'plant:source' to 'plant_sour'
# WARNING:fiona._env:Normalized/laundered field name: 'plant:storage' to 'plant_stor'
# WARNING:fiona._env:Normalized/laundered field name: 'public_transport' to 'public_tra'
# WARNING:fiona._env:Normalized/laundered field name: 'pumping_station' to 'pumping_st'
# WARNING:fiona._env:Normalized/laundered field name: 'railway:position' to 'railway_po'
# WARNING:fiona._env:Normalized/laundered field name: 'recording:automated' to 'recording_'
# WARNING:fiona._env:Normalized/laundered field name: 'recording:remote' to 'recordin_1'
# WARNING:fiona._env:Normalized/laundered field name: 'ref:nrhp' to 'ref_nrhp'
# WARNING:fiona._env:Normalized/laundered field name: 'seamark:name' to 'seamark_na'
# WARNING:fiona._env:Normalized/laundered field name: 'seamark:type' to 'seamark_ty'
# WARNING:fiona._env:Normalized/laundered field name: 'source:date' to 'source_dat'
# WARNING:fiona._env:Normalized/laundered field name: 'source:name' to 'source_nam'
# WARNING:fiona._env:Normalized/laundered field name: 'source_date' to 'source_d_1'
# WARNING:fiona._env:Normalized/laundered field name: 'works:type' to 'works_type'
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.

# %%
# residential buildings data
get_res_buildings('alaska')
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# ...
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.2
# INFO:esy.osmfilter.pre_filter:1.3
# INFO:esy.osmfilter.pre_filter:2
# INFO:esy.osmfilter.pre_filter:3
# INFO:esy.osmfilter.pre_filter:Outputfile    : /content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/alaska-res_buildings.json
# Size          : 22623           kbyte
# Time Elapsed  : 241.51          s
# 12295
# 12295
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:63: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# WARNING:fiona._env:Normalized/laundered field name: 'addr:city' to 'addr_city'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:country' to 'addr_count'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:housename' to 'addr_house'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:housenumber' to 'addr_hou_1'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:postcode' to 'addr_postc'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:province' to 'addr_provi'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:state' to 'addr_state'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:street' to 'addr_stree'
# WARNING:fiona._env:Normalized/laundered field name: 'addr:unit' to 'addr_unit'
# WARNING:fiona._env:Normalized/laundered field name: 'air_conditioning' to 'air_condit'
# WARNING:fiona._env:Normalized/laundered field name: 'brand:wikidata' to 'brand_wiki'
# WARNING:fiona._env:Normalized/laundered field name: 'brand:wikipedia' to 'brand_wi_1'
# WARNING:fiona._env:Normalized/laundered field name: 'building:commercial' to 'building_c'
# WARNING:fiona._env:Normalized/laundered field name: 'building:flats' to 'building_f'
# WARNING:fiona._env:Normalized/laundered field name: 'building:levels' to 'building_l'
# WARNING:fiona._env:Normalized/laundered field name: 'building:material' to 'building_m'
# WARNING:fiona._env:Normalized/laundered field name: 'building:use' to 'building_u'
# WARNING:fiona._env:Normalized/laundered field name: 'check_date:opening_hours' to 'check_date'
# WARNING:fiona._env:Normalized/laundered field name: 'community_centre' to 'community_'
# WARNING:fiona._env:Normalized/laundered field name: 'community_centre:for' to 'communit_1'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:facebook' to 'contact_fa'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:instagram' to 'contact_in'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:website' to 'contact_we'
# WARNING:fiona._env:Normalized/laundered field name: 'contact:youtube' to 'contact_yo'
# WARNING:fiona._env:Normalized/laundered field name: 'denomination' to 'denominati'
# WARNING:fiona._env:Normalized/laundered field name: 'description' to 'descriptio'
# WARNING:fiona._env:Normalized/laundered field name: 'designation' to 'designatio'
# WARNING:fiona._env:Normalized/laundered field name: 'drinking_water' to 'drinking_w'
# WARNING:fiona._env:Normalized/laundered field name: 'guest_house' to 'guest_hous'
# WARNING:fiona._env:Normalized/laundered field name: 'heritage:operator' to 'heritage_o'
# WARNING:fiona._env:Normalized/laundered field name: 'information' to 'informatio'
# WARNING:fiona._env:Normalized/laundered field name: 'internet_access' to 'internet_a'
# WARNING:fiona._env:Normalized/laundered field name: 'internet_access:fee' to 'internet_1'
# WARNING:fiona._env:Normalized/laundered field name: 'maxheight:physical' to 'maxheight_'
# WARNING:fiona._env:Normalized/laundered field name: 'name:en' to 'name_en'
# WARNING:fiona._env:Normalized/laundered field name: 'nohousenumber' to 'nohousenum'
# WARNING:fiona._env:Normalized/laundered field name: 'nrhp:inscription_date' to 'nrhp_inscr'
# WARNING:fiona._env:Normalized/laundered field name: 'official_name' to 'official_n'
# WARNING:fiona._env:Normalized/laundered field name: 'opening_hours' to 'opening_ho'
# WARNING:fiona._env:Normalized/laundered field name: 'operator:type' to 'operator_t'
# WARNING:fiona._env:Normalized/laundered field name: 'operator:wikidata' to 'operator_w'
# WARNING:fiona._env:Normalized/laundered field name: 'operator:wikipedia' to 'operator_1'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:cash' to 'payment_ca'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:credit_cards' to 'payment_cr'
# WARNING:fiona._env:Normalized/laundered field name: 'payment:debit_cards' to 'payment_de'
# WARNING:fiona._env:Normalized/laundered field name: 'postal_code' to 'postal_cod'
# WARNING:fiona._env:Normalized/laundered field name: 'ref:nrhp' to 'ref_nrhp'
# WARNING:fiona._env:Normalized/laundered field name: 'ref:nris' to 'ref_nris'
# WARNING:fiona._env:Normalized/laundered field name: 'reservation' to 'reservatio'
# WARNING:fiona._env:Normalized/laundered field name: 'residential' to 'residentia'
# WARNING:fiona._env:Normalized/laundered field name: 'roof:colour' to 'roof_colou'
# WARNING:fiona._env:Normalized/laundered field name: 'roof:levels' to 'roof_level'
# WARNING:fiona._env:Normalized/laundered field name: 'roof:shape' to 'roof_shape'
# WARNING:fiona._env:Normalized/laundered field name: 'service_times' to 'service_ti'
# WARNING:fiona._env:Normalized/laundered field name: 'shelter_type' to 'shelter_ty'
# WARNING:fiona._env:Normalized/laundered field name: 'social_facility' to 'social_fac'
# WARNING:fiona._env:Normalized/laundered field name: 'social_facility:for' to 'social_f_1'
# WARNING:fiona._env:Normalized/laundered field name: 'source:date' to 'source_dat'
# WARNING:fiona._env:Normalized/laundered field name: 'source:location' to 'source_loc'
# WARNING:fiona._env:Normalized/laundered field name: 'source:name' to 'source_nam'
# WARNING:fiona._env:Normalized/laundered field name: 'source:position' to 'source_pos'
# WARNING:fiona._env:Normalized/laundered field name: 'toilets:wheelchair' to 'toilets_wh'
# WARNING:fiona._env:Normalized/laundered field name: 'tower:construction' to 'tower_cons'
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.

# %%
import pandas as pd
#Check the size of the data
res_data=pd.read_json('/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/alaska-res_buildings.json')
len(res_data)
# Out:
# 102032

# %%
#Check the size of the data
com_data=pd.read_json('/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/alaska-com_buildings.json')
len(com_data)
# Out:
# 42907

# %%
#Check the size of the data
ind_data=pd.read_json('/content/drive/MyDrive/ACEP_Data_Team/Railbelt_line/Script_data/alaska-ind_buildings.json')
len(ind_data)
# Out:
# 6320
